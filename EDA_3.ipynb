# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Compiled_descriptors.csv')

# %%
df=df.iloc[:,1:]

# %%
df['IC50']=pd.read_csv('IC50 (1).csv')

# %%
df['IC50'].quantile(0.33)
# Out:
# 3050.0

# %%
df['IC50'].quantile(0.66)
# Out:
# 10217.6

# %%
m = [0 if ele <= 1900 else 1 if ele <=5800 else 2 for ele in df['IC50']]

# %%
df['Class']=m

# %%
df_classification2=df.drop('IC50',axis=1)

# %%
df_classification2.to_csv('Compiled_descriptors_2.csv')

# %%
plt.scatter(df['Class'],df['IC50'],c=df['Class'])
plt.ylim(0,9000)
plt.grid()

# %%
sns.distplot(df['Class'])
# Out:
# C:\Users\Akshat\AppData\Local\Temp\ipykernel_5660\693553272.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Class'])
# <Axes: xlabel='Class', ylabel='Density'>

# %%
abs(df.drop('IC50',axis=1).corr()['Class']).sort_values(ascending= False)
# Out:
# Class     1.000000
# C-005     0.332119
# C-016     0.311954
# MATS2p    0.299658
# MATS2i    0.280997
#             ...
# GATS7e    0.002601
# CENT      0.002564
# MATS6v    0.001726
# MATS8p    0.001682
# O%        0.001006
# Name: Class, Length: 738, dtype: float64

# %%
mask1=df['C-005']==0
mask2=df['C-005']==1
mask3=df['C-005']==2
mask4=df['C-005']==3
mask5=df['C-005']==4
mask6=df['C-005']==5
mask7=df['C-005']==6

# %%
df[mask1]['Class'].value_counts()
# Out:
# Class
# 2    180
# 1     70
# 0     41
# Name: count, dtype: int64

# %%
l=df[mask1]['Class'].value_counts().to_list()

# %%
j=[180,70,41,45,28,29,47,32,40,6,1,10,6,11,17,0,0,2,0,0,4]

# %%
len(j)
# Out:
# 21

# %%
sum(j)
# Out:
# 569

# %%
dictonary
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 dictonary
#
# NameError: name 'dictonary' is not defined

# %%
j=l[2::3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 j=l[2::3]
#
# NameError: name 'l' is not defined

# %%
j.append(0)

# %%
j
# Out:
# [180, 70, 41, 45, 28, 29, 47, 32, 40, 6, 1, 10, 6, 11, 17, 0, 0, 2, 0, 0, 4, 0]

# %%
dictonary={'Class_2':j[::3],'Class_1':j[1::3],'Class_0':j[2::3]}

# %%
df_plotting=pd.DataFrame(dictonary)

# %%
df_plotting['C-005']=list(np.arange(7))

# %%
df_plotting
# Out:
#    Class_2  Class_1  Class_0  C-005
# 0      180       70       41      0
# 1       45       28       29      1
# 2       47       32       40      2
# 3        6        1       10      3
# 4        6       11       17      4
# 5        0        0        2      5
# 6        0        0        4      6

# %%
plt.bar(np.arange(7)-0.2, df_plotting['Class_2'],width=0.2,label='Class_2')
plt.bar(np.arange(7)-0, df_plotting['Class_1'],width=0.2,label='Class_1')
plt.bar(np.arange(7)+0.2, df_plotting['Class_0'],width=0.2,label='Class_0')
plt.xticks(np.arange(7),df_plotting['C-005'])
plt.ylabel('number_of_values')
plt.xlabel('classes_C-005')
plt.legend()
plt.grid()
plt.show()

# %%
plt.scatter(y=df['IC50'],x=df['MATS2p'],c=df['Class'])
plt.ylim(0,24000)
plt.ylabel('IC50')
plt.xlabel('MATS2p')
# Out:
# Text(0.5, 0, 'MATS2p')

# %%
mask_1=df['MATS2p']<=0.0
mask_2=df['MATS2p']<=0.2 
mask_4=df['MATS2p']>=0.0
mask_3=df['MATS2p']>=0.2

# %%
sns.distplot(df[mask_3]['Class'],hist=False)
plt.ylabel('MATS2p greater than 0.2')
# Out:
# C:\Users\Akshat\AppData\Local\Temp\ipykernel_5660\3971370399.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[mask_3]['Class'],hist=False)
# Text(0, 0.5, 'MATS2p greater than 0.2')

# %%
plt.bar
